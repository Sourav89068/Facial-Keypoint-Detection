# %% [markdown]
# # for RGB images

# %%
from prediction import predict

# %%
predict("image0.jpeg")

# %% [markdown]
# # for images on test data

# %%
import pandas as pd
import numpy as np
test_data=pd.read_csv("test.csv")

# %%
from prediction import predict_on_test_set_images

# %%
predict_on_test_set_images(test_data,np.random.randint(0,40,10))
